# %% [markdown]
# # Introduzione

# %% [markdown]
# L'environment **anaconda** da utilizzare è **webscraping**.

# %% [markdown]
# # Importazione pacchetti

# %% [markdown]
# Importare i vari pacchetti necessari  per eseguire le azioni elencate nell'introduzione:
#    - selenium (per navigare sulle pagine web)
#    - request (scaricare dati da internet)
#    - bs4 (beautiful soup, manipolare gli html)
#    - os (navigare nei file del computer)
#    - pandas (manipolazione/esportazione dataframes)
#    - time (per i time sleep)
#    - datetime (gestire i timestamp, ovvero le stringhe contenti date e orari)
#    - tqdm (per le barre di progresso)
#    - re (lavorare con regex e le regular expressions)

# %%
#%% Pacchetti
## Importazione pacchetti per selenium
# Altre funzionalità di selenium
#from selenium.webdriver.support.ui import WebDriverWait
#from selenium.webdriver.common.by import By
#from selenium.webdriver.support import expected_conditions as EC
#from selenium.webdriver.common.action_chains import ActionChains
#from selenium.webdriver.chrome.options import Options
#from selenium.webdriver.common.keys import Keys
#from selenium.webdriver.common.actions.wheel_input import ScrollOrigin
#from selenium.common.exceptions import TimeoutException
#from webdriver_manager.chrome import ChromeDriverManager
#-------##-------##-------##-------##-------##-------##-------##-------##-------##-------#
import requests # Importazione pacchetti per scaricare dati da internet
from bs4 import BeautifulSoup # Importazione pacchetti per gestire HTML
import os # Interagire con i file del pc 
from tqdm import tqdm as tqdm # Importazione pacchetti per barra di progresso
import re # Importazione pacchetti per utilizzare regex e le regular expression
import pandas as pd  # Importazione pacchetti per lavorare con i dataframe
import warnings # Importazione pacchetti per gestire i warnings, ad esempio quelli di pandas
from datetime import datetime# Importazione pacchetti per lavorare con timestamps, orari e date
import numpy as np 

#pd.set_option('display.max_rows', None)

# %%
# Directory principale dello scraper, ove vi sono gli script e gli html devono essere posizionati
path_main_directory = '/Users/mattia/Desktop/Università/Data Science in Python/14) Web Scraping/Scraping-from-booking'

# %%
# Importare l'html del file in questione
with open(f"{path_main_directory}/html/html_final.txt","r") as f:
   html = f.read()

html_bs4 = BeautifulSoup(html,'html.parser')
proprietà = html_bs4.find_all("div",{"data-testid":"property-card"})

booking_dataframe = pd.DataFrame(columns=[
    "titolo",
    "recensione_voto_numerico",
    "recensione_voto_parola",
    "numero_recensioni",
    "date",
    "permanenza",
    "prezzo",
    "distanza_centro",
    "indirizzo",
    "stelle",
    "valutazione_booking",
    "descrizione_camera",
    "configurazione_camera",
    "descrizione_unprocessed"
])


for post in tqdm(proprietà):
   # Prendere il titolo della proprietà
   titolo = post.find("div",{"data-testid":"title"}).text
   
   # Selezionare la tag delle recensioni
   review = post.find("div",{"data-testid":"review-score"})#.text
   
   ## In caso di nuovi insererimenti  (novità su booking) non ci sono votazioni.
   if review != None:
      ## Estrarre voto numerico dalla tag delle recensioni
      recensione_voto_numerico = review.find("div",{"aria-hidden":"true"}).text

      ## Estrarre il voto in parole ed il numero di recensioni dalla tag delle recensioni
      info_recensioni = review.find("div",{"aria-hidden":"false"})
      for div in info_recensioni:
         if ("recensioni" in div.text.lower()) or ("recensione" in div.text.lower()):
            numero_recensioni = div.text

         else:
            recensione_voto_parola = div.text
   else:
      recensione_voto_numerico = "Novità su booking"
      numero_recensioni = "Novità su booking"
      recensione_voto_parola = "Novità su booking"
         

   # Selezionare la tag dei prezzi e per il numero di persone e notti
   info_costi = post.find("div",{"data-testid":"availability-rate-wrapper"})#.text

   ## Prezzo per notti e numero di persone
   permanenza =  info_costi.find("div",{"data-testid":"price-for-x-nights"}).text
   
   ## Prezzo
   prezzo =  info_costi.find("span",{"data-testid":"price-and-discounted-price"}).text


   # Selezionare la località
   ## Distanza dal centro
   distanza_centro = post.find("span",{"data-testid":"distance"}).text


   indirizzo = post.find("span",{"data-testid":"address"}).text


   # Valutazioni

   ## Rating stars
   rating_stars = post.find("div",{"data-testid":"rating-stars"})
   
   ### La proprietà potrebbe non essere un albergo e quindi non avere stelle
   if rating_stars != None:
      stelle = len(rating_stars.find_all("div"))
   else:
      stelle = np.nan
         
   ## Rating booking
   rating_booking = post.find("div",{"data-testid":"rating-squares"})
   
   ### La proprietà potrebbe  essere un albergo e quindi non avere valutazione booking
   if rating_booking != None:
      valutazione_booking = len(rating_booking.find_all("div"))
   else:
      valutazione_booking = np.nan


   # Descrizione della camera offerta
   
   ## Tutta la descrizione
   descrizione_unprocessed = post.find("div",{"data-testid":"recommended-units"}).text
   
   ## tag descrizione per estrarre cose estraibili
   descrizione = post.find("div",{"data-testid":"recommended-units"})

   ### Descrizione camera
   descrizione_camera = descrizione.find("h4").text
   
   ### Configurazione camera, che potrebbe non esistere 
   configurazione_camera = descrizione.find("div",{"data-testid":"property-card-unit-configuration"})

   if  configurazione_camera != None:
      configurazione_camera = configurazione_camera.text

   else:
      configurazione_camera = "Configurazione camera non disponibile"



   # Crea il dizionario con i dati della singola proprietà
   informazioni_singola_proprietà = {  "titolo": titolo,
                                       "recensione_voto_numerico": recensione_voto_numerico,
                                       "recensione_voto_parola": recensione_voto_parola,
                                       "numero_recensioni": numero_recensioni,
                                       "date": "1 agosto - 2 agosto",
                                       "permanenza": permanenza,
                                       "prezzo": prezzo,
                                       "distanza_centro": distanza_centro,
                                       "indirizzo": indirizzo,
                                       "stelle": stelle,
                                       "valutazione_booking": valutazione_booking,
                                       "descrizione_camera": descrizione_camera,
                                       "configurazione_camera": configurazione_camera,
                                       "descrizione_unprocessed": descrizione_unprocessed

                                    }
   
   # Aggiunge direttamente come nuova riga
   booking_dataframe.loc[len(booking_dataframe)] = informazioni_singola_proprietà
# Out:
# 100%|██████████| 70/70 [00:00<00:00, 526.81it/s]

# %%
booking_dataframe.to_csv(f"{path_main_directory}/bookingTerni.csv")

# %%
pd.set_option('display.max_rows', None)
booking_dataframe.sort_values(by="titolo")
# Out:
#                                                titolo  \
# 69   -15min Marmore- Ampio Appartamento Terra e Cuore
# 15                                     A casa di Alma
# 48                                          A&F House
# 56                                      Acqua Marmore
# 52                             Alloggi Primavera Anna
# 46                          Alloggi Primavera Matilde
# 59                         Alloggio tra Terni e Narni
# 22                         Appartamenti Il Cerqueto 2
# 34                Appartamenti Natura e Terra Marmore
# 26                                           Aryhouse
# 5                                      Asso Residence
# 9                               Asso Residence Centro
# 8                                 Asso Residence GOLD
# 6                             Asso Residence Ospedale
# 28                            Asso Residence Stazione
# 3                                    B&B Angolo Verde
# 7                                     B&B Villa Maria
# 55                    Bed and Breakfast San Valentino
# 58                                  Belvedere Valenza
# 57                                         Bice house
# 64                          Bilocale degli Innamorati
# 60                                Casa Vacanze Chiara
# 53                                      Casa di milly
# 31                                     Casa nel Verde
# 11                                         Civico 100
# 45                                          Civico 66
# 44                                 Civico Sessantasei
# 12                             Classic Hotel Tulipano
# 1                                          Cospea B&B
# 65                                     Cuore di Terni
# 67  Favolosa "Dimora del Capriolo" con Giardino e ...
# 66                                  Frantoio Pistelli
# 29                                       G&Gapartment
# 0                                      Hotel De Paris
# 25                                 Hotel Garden Terni
# 17                    Hotel Michelangelo Palace & SPA
# 18                                    Hotel Valentino
# 37                                  IL TEATRO ALLOGGI
# 30                              Il Giardino di Venere
# 42  Interamna House, intero appartamento exclusive...
# 40                               La Casa nella Contea
# 32          La Casetta- Bilocale con giardino privato
# 43                            La Collina Dei Castagni
# 62                                 La Fattoria di Ema
# 54                                          La Severa
# 68                                        La Severa 2
# 21                                    La casa di Alan
# 41                                    La casa di Emma
# 61     La casa di Glenda bis - alloggio zona ospedale
# 63                         La casa di Glenda ospedale
# 19                                Le Camere di Ettore
# 33                                         M&M’s Home
# 38         Palmira House - delizioso bilocale for two
# 23                               Pied-à-terre ADELMA
# 47                                            RIO bed
# 10                                Residence Viviverde
# 2                                  Rosy Bed&Breakfast
# 35                                 San Francesco Home
# 4                          Santa Filomena Guest House
# 50                                Tana per gli ospiti
# 51                                    Terni In Centro
# 49                                    The Lover House
# 27                                        Tre Colonne
# 36                        Tre Monumenti Luxury Suites
# 14                                           Via Roma
# 39                                            WHITE 2
# 16                                       Welcome home
# 24                                              White
# 13                                       angolo verde
# 20                                          as maison
#
#    recensione_voto_numerico recensione_voto_parola  numero_recensioni  \
# 69        Novità su booking      Novità su booking  Novità su booking
# 15                      9,2            Eccellente      101 recensioni
# 48                      8,7              Favoloso        6 recensioni
# 56                      8,8              Favoloso       82 recensioni
# 52        Novità su booking      Novità su booking  Novità su booking
# 46                       10           Eccezionale        1 recensione
# 59                      9,5           Eccezionale       19 recensioni
# 22                      8,2                Ottimo      153 recensioni
# 34                      8,9              Favoloso      134 recensioni
# 26                      9,8           Eccezionale       27 recensioni
# 5                       8,2                Ottimo    1.341 recensioni
# 9                       7,9                 Buono      980 recensioni
# 8                       8,4                Ottimo       17 recensioni
# 6                       8,8              Favoloso    1.297 recensioni
# 28                      7,9                 Buono       61 recensioni
# 3                       8,6              Favoloso      219 recensioni
# 7                       9,3            Eccellente      253 recensioni
# 55                      7,1                 Buono       46 recensioni
# 58                      6,8       Punteggio medio       14 recensioni
# 57                      9,2            Eccellente       20 recensioni
# 64                      8,2                Ottimo       57 recensioni
# 60                      9,7           Eccezionale        3 recensioni
# 53                       10           Eccezionale        1 recensione
# 31                      7,8                 Buono      141 recensioni
# 11                      8,4                Ottimo       49 recensioni
# 45                      9,3            Eccellente        9 recensioni
# 44                      9,8           Eccezionale        6 recensioni
# 12                      7,5                 Buono      406 recensioni
# 1                       9,0            Eccellente      674 recensioni
# 65        Novità su booking      Novità su booking  Novità su booking
# 67                      9,3            Eccellente       13 recensioni
# 66                      9,0            Eccellente        6 recensioni
# 29                      7,8                 Buono       89 recensioni
# 0                       7,2                 Buono      869 recensioni
# 25                      7,8                 Buono      477 recensioni
# 17                      7,8                 Buono      669 recensioni
# 18                      8,5                Ottimo      754 recensioni
# 37                      8,6              Favoloso      112 recensioni
# 30                      8,1                Ottimo       86 recensioni
# 42                      9,0            Eccellente        3 recensioni
# 40                      9,9           Eccezionale       21 recensioni
# 32                      9,4            Eccellente       56 recensioni
# 43                      9,0            Eccellente        1 recensione
# 62                      7,6                 Buono       27 recensioni
# 54                      9,3            Eccellente       51 recensioni
# 68                      8,4                Ottimo       11 recensioni
# 21                      7,8                 Buono      257 recensioni
# 41                      9,1            Eccellente       90 recensioni
# 61                      9,5           Eccezionale       36 recensioni
# 63                      9,2            Eccellente       23 recensioni
# 19                      8,9              Favoloso      103 recensioni
# 33                      9,2            Eccellente      168 recensioni
# 38                      9,7           Eccezionale      113 recensioni
# 23        Novità su booking      Novità su booking  Novità su booking
# 47                      9,7           Eccezionale        4 recensioni
# 10                      8,8              Favoloso      620 recensioni
# 2                       9,0            Eccellente      330 recensioni
# 35                      8,8              Favoloso       17 recensioni
# 4                       9,7           Eccezionale       11 recensioni
# 50                      8,8              Favoloso       66 recensioni
# 51                      7,5                 Buono       51 recensioni
# 49                      8,8              Favoloso        6 recensioni
# 27                      9,1            Eccellente       21 recensioni
# 36                       10           Eccezionale        3 recensioni
# 14                      9,2            Eccellente       76 recensioni
# 39                      8,8              Favoloso       19 recensioni
# 16                      9,6           Eccezionale       56 recensioni
# 24                      8,6              Favoloso      218 recensioni
# 13                      8,0                Ottimo        7 recensioni
# 20                      9,5           Eccezionale      109 recensioni
#
#                    date         permanenza prezzo     distanza_centro  \
# 69  1 agosto - 2 agosto  1 notte, 2 adulti  € 182   2,9 km dal centro
# 15  1 agosto - 2 agosto  1 notte, 2 adulti   € 81   1,2 km dal centro
# 48  1 agosto - 2 agosto  1 notte, 2 adulti  € 107   2,2 km dal centro
# 56  1 agosto - 2 agosto  1 notte, 2 adulti  € 125   5,5 km dal centro
# 52  1 agosto - 2 agosto  1 notte, 2 adulti  € 141   2,8 km dal centro
# 46  1 agosto - 2 agosto  1 notte, 2 adulti  € 115   2,8 km dal centro
# 59  1 agosto - 2 agosto  1 notte, 2 adulti  € 128   3,9 km dal centro
# 22  1 agosto - 2 agosto  1 notte, 2 adulti   € 74   1,7 km dal centro
# 34  1 agosto - 2 agosto  1 notte, 2 adulti  € 113   5,5 km dal centro
# 26  1 agosto - 2 agosto  1 notte, 2 adulti   € 85   1,1 km dal centro
# 5   1 agosto - 2 agosto  1 notte, 2 adulti   € 79   2,1 km dal centro
# 9   1 agosto - 2 agosto  1 notte, 2 adulti   € 81     40 m dal centro
# 8   1 agosto - 2 agosto  1 notte, 2 adulti   € 94   1,9 km dal centro
# 6   1 agosto - 2 agosto  1 notte, 2 adulti   € 89   1,9 km dal centro
# 28  1 agosto - 2 agosto  1 notte, 2 adulti   € 94   1,1 km dal centro
# 3   1 agosto - 2 agosto  1 notte, 2 adulti   € 69   2,6 km dal centro
# 7   1 agosto - 2 agosto  1 notte, 2 adulti   € 74   2,7 km dal centro
# 55  1 agosto - 2 agosto  1 notte, 2 adulti   € 99   2,2 km dal centro
# 58  1 agosto - 2 agosto  1 notte, 2 adulti   € 97   3,8 km dal centro
# 57  1 agosto - 2 agosto  1 notte, 2 adulti  € 144   5,3 km dal centro
# 64  1 agosto - 2 agosto  1 notte, 2 adulti  € 107   0,8 km dal centro
# 60  1 agosto - 2 agosto  1 notte, 2 adulti  € 104   3,5 km dal centro
# 53  1 agosto - 2 agosto  1 notte, 2 adulti   € 80   2,1 km dal centro
# 31  1 agosto - 2 agosto  1 notte, 2 adulti   € 59   2,8 km dal centro
# 11  1 agosto - 2 agosto  1 notte, 2 adulti   € 72   0,8 km dal centro
# 45  1 agosto - 2 agosto  1 notte, 2 adulti  € 100   0,8 km dal centro
# 44  1 agosto - 2 agosto  1 notte, 2 adulti  € 104   0,8 km dal centro
# 12  1 agosto - 2 agosto  1 notte, 2 adulti  € 128   1,7 km dal centro
# 1   1 agosto - 2 agosto  1 notte, 2 adulti   € 55   1,7 km dal centro
# 65  1 agosto - 2 agosto  1 notte, 2 adulti   € 96   0,8 km dal centro
# 67  1 agosto - 2 agosto  1 notte, 2 adulti  € 216   2,9 km dal centro
# 66  1 agosto - 2 agosto  1 notte, 2 adulti   € 81     2 km dal centro
# 29  1 agosto - 2 agosto  1 notte, 2 adulti  € 129   1,5 km dal centro
# 0   1 agosto - 2 agosto  1 notte, 2 adulti   € 69   0,9 km dal centro
# 25  1 agosto - 2 agosto  1 notte, 2 adulti  € 138   1,2 km dal centro
# 17  1 agosto - 2 agosto  1 notte, 2 adulti  € 174     1 km dal centro
# 18  1 agosto - 2 agosto  1 notte, 2 adulti  € 258   0,9 km dal centro
# 37  1 agosto - 2 agosto  1 notte, 2 adulti   € 93   0,8 km dal centro
# 30  1 agosto - 2 agosto  1 notte, 2 adulti   € 74   5,5 km dal centro
# 42  1 agosto - 2 agosto  1 notte, 2 adulti   € 97   0,5 km dal centro
# 40  1 agosto - 2 agosto  1 notte, 2 adulti   € 92   5,4 km dal centro
# 32  1 agosto - 2 agosto  1 notte, 2 adulti  € 109   1,3 km dal centro
# 43  1 agosto - 2 agosto  1 notte, 2 adulti  € 134   7,9 km dal centro
# 62  1 agosto - 2 agosto  1 notte, 2 adulti   € 69  11,2 km dal centro
# 54  1 agosto - 2 agosto  1 notte, 2 adulti   € 94   1,4 km dal centro
# 68  1 agosto - 2 agosto  1 notte, 2 adulti   € 96   1,4 km dal centro
# 21  1 agosto - 2 agosto  1 notte, 2 adulti   € 80   1,6 km dal centro
# 41  1 agosto - 2 agosto  1 notte, 2 adulti   € 94   2,6 km dal centro
# 61  1 agosto - 2 agosto  1 notte, 2 adulti   € 94   2,2 km dal centro
# 63  1 agosto - 2 agosto  1 notte, 2 adulti   € 90   2,2 km dal centro
# 19  1 agosto - 2 agosto  1 notte, 2 adulti   € 79   1,1 km dal centro
# 33  1 agosto - 2 agosto  1 notte, 2 adulti   € 85     1 km dal centro
# 38  1 agosto - 2 agosto  1 notte, 2 adulti   € 94    400 m dal centro
# 23  1 agosto - 2 agosto  1 notte, 2 adulti   € 53   1,1 km dal centro
# 47  1 agosto - 2 agosto  1 notte, 2 adulti   € 94   0,9 km dal centro
# 10  1 agosto - 2 agosto  1 notte, 2 adulti   € 76   3,6 km dal centro
# 2   1 agosto - 2 agosto  1 notte, 2 adulti   € 77     1 km dal centro
# 35  1 agosto - 2 agosto  1 notte, 2 adulti   € 84    400 m dal centro
# 4   1 agosto - 2 agosto  1 notte, 2 adulti   € 74     1 km dal centro
# 50  1 agosto - 2 agosto  1 notte, 2 adulti   € 81   2,3 km dal centro
# 51  1 agosto - 2 agosto  1 notte, 2 adulti  € 124   0,8 km dal centro
# 49  1 agosto - 2 agosto  1 notte, 2 adulti   € 82   8,3 km dal centro
# 27  1 agosto - 2 agosto  1 notte, 2 adulti   € 76   0,5 km dal centro
# 36  1 agosto - 2 agosto  1 notte, 2 adulti  € 113     1 km dal centro
# 14  1 agosto - 2 agosto  1 notte, 2 adulti   € 84   0,7 km dal centro
# 39  1 agosto - 2 agosto  1 notte, 2 adulti   € 73   0,8 km dal centro
# 16  1 agosto - 2 agosto  1 notte, 2 adulti   € 87   0,6 km dal centro
# 24  1 agosto - 2 agosto  1 notte, 2 adulti   € 67   0,6 km dal centro
# 13  1 agosto - 2 agosto  1 notte, 2 adulti   € 63   2,6 km dal centro
# 20  1 agosto - 2 agosto  1 notte, 2 adulti   € 89   2,3 km dal centro
#
#    indirizzo  stelle  valutazione_booking  \
# 69     Terni     NaN                  NaN
# 15     Terni     NaN                  3.0
# 48     Terni     NaN                  NaN
# 56     Terni     NaN                  3.0
# 52     Terni     NaN                  NaN
# 46     Terni     NaN                  3.0
# 59     Terni     NaN                  3.0
# 22     Terni     NaN                  3.0
# 34     Terni     NaN                  3.0
# 26     Terni     NaN                  3.0
# 5      Terni     NaN                  3.0
# 9      Terni     NaN                  3.0
# 8      Terni     NaN                  3.0
# 6      Terni     NaN                  3.0
# 28     Terni     NaN                  3.0
# 3      Terni     NaN                  3.0
# 7      Terni     NaN                  4.0
# 55     Terni     NaN                  3.0
# 58     Terni     NaN                  3.0
# 57     Terni     NaN                  4.0
# 64     Terni     NaN                  3.0
# 60     Terni     NaN                  4.0
# 53     Terni     NaN                  NaN
# 31     Terni     NaN                  3.0
# 11     Terni     NaN                  3.0
# 45     Terni     NaN                  3.0
# 44     Terni     NaN                  3.0
# 12     Terni     3.0                  NaN
# 1      Terni     NaN                  3.0
# 65     Terni     NaN                  NaN
# 67     Terni     NaN                  3.0
# 66     Terni     NaN                  NaN
# 29     Terni     NaN                  3.0
# 0      Terni     3.0                  NaN
# 25     Terni     4.0                  NaN
# 17     Terni     4.0                  NaN
# 18     Terni     4.0                  NaN
# 37     Terni     NaN                  3.0
# 30     Terni     NaN                  3.0
# 42     Terni     NaN                  3.0
# 40     Terni     NaN                  3.0
# 32     Terni     NaN                  4.0
# 43     Terni     NaN                  4.0
# 62     Terni     NaN                  3.0
# 54     Terni     NaN                  4.0
# 68     Terni     NaN                  4.0
# 21     Terni     NaN                  3.0
# 41     Terni     NaN                  3.0
# 61     Terni     NaN                  3.0
# 63     Terni     NaN                  3.0
# 19     Terni     NaN                  3.0
# 33     Terni     NaN                  3.0
# 38     Terni     NaN                  4.0
# 23     Terni     NaN                  NaN
# 47     Terni     NaN                  3.0
# 10     Terni     NaN                  4.0
# 2      Terni     NaN                  4.0
# 35     Terni     NaN                  3.0
# 4      Terni     NaN                  3.0
# 50     Terni     NaN                  3.0
# 51     Terni     NaN                  3.0
# 49     Terni     NaN                  4.0
# 27     Terni     NaN                  3.0
# 36     Terni     NaN                  3.0
# 14     Terni     NaN                  3.0
# 39     Terni     NaN                  3.0
# 16     Terni     NaN                  4.0
# 24     Terni     NaN                  3.0
# 13     Terni     NaN                  NaN
# 20     Terni     NaN                  3.0
#
#                                    descrizione_camera  \
# 69                 Appartamento con 2 Camere da Letto
# 15              Camera Matrimoniale con Bagno Privato
# 48                 Appartamento con 2 Camere da Letto
# 56                         Appartamento - Piano Terra
# 52                          Ampia Camera Matrimoniale
# 46              Camera Matrimoniale con Bagno Privato
# 59                         Casa con 2 Camere da Letto
# 22                 Appartamento con 1 Camera da Letto
# 34                    Appartamento con Vista Giardino
# 26                 Appartamento con 1 Camera da Letto
# 5                        Camera Matrimoniale Standard
# 9        Camera Matrimoniale/Doppia con Letti Singoli
# 8                               Camera King Superior
# 6                             Appartamento Monolocale
# 28                       Camera Matrimoniale Standard
# 3                                 Camera Matrimoniale
# 7                            Camera King con Balcone
# 55                                Camera Matrimoniale
# 58                                Appartamento Attico
# 57                 Appartamento con 3 Camere da Letto
# 64                 Appartamento con 1 Camera da Letto
# 60                Casa Vacanze con 3 Camere da Letto
# 53                 Appartamento con 1 Camera da Letto
# 31                         Casa con 1 Camera da Letto
# 11                                Camera Matrimoniale
# 45                 Appartamento con 1 Camera da Letto
# 44                 Appartamento con 1 Camera da Letto
# 12                       Camera Matrimoniale Standard
# 1                     Camera Doppia con Letti Singoli
# 65                 Appartamento con 2 Camere da Letto
# 67                 Appartamento con 1 Camera da Letto
# 66                 Appartamento con 1 Camera da Letto
# 29                 Appartamento con 2 Camere da Letto
# 0                     Camera Doppia con Letti Singoli
# 25  Camera Classic Matrimoniale/Doppia con Letti S...
# 17                         Camera Matrimoniale Deluxe
# 18                                 Suite con Balcone
# 37                         Appartamento - Piano Terra
# 30                             Camera Tripla Standard
# 42                 Appartamento con 3 Camere da Letto
# 40                 Appartamento con 1 Camera da Letto
# 32                 Appartamento con 1 Camera da Letto
# 43              Camera Matrimoniale con Vista Piscina
# 62                                Camera Matrimoniale
# 54                 Appartamento con 1 Camera da Letto
# 68                 Appartamento con 1 Camera da Letto
# 21                                Camera Matrimoniale
# 41                 Appartamento con 1 Camera da Letto
# 61                 Appartamento con 1 Camera da Letto
# 63                 Appartamento con 1 Camera da Letto
# 19              Camera Matrimoniale con Bagno Privato
# 33                                Camera Matrimoniale
# 38                 Appartamento con 1 Camera da Letto
# 23                 Appartamento con 2 Camere da Letto
# 47                                Camera Matrimoniale
# 10                              Appartamento Standard
# 2      Camera Matrimoniale con Bagno Privato Esterno
# 35                 Appartamento con 1 Camera da Letto
# 4                                       Camera Tripla
# 50                                         Monolocale
# 51                                      Appartamento
# 49  Camera Standard Matrimoniale/Doppia con Letti ...
# 27                 Appartamento con 1 Camera da Letto
# 36                   Appartamento con Vista e Balcone
# 14                           Camera King con Balcone
# 39                 Appartamento con 1 Camera da Letto
# 16                 Appartamento con 2 Camere da Letto
# 24                                Camera Matrimoniale
# 13                                Camera Matrimoniale
# 20                 Appartamento con 1 Camera da Letto
#
#                                 configurazione_camera  \
# 69              Configurazione camera non disponibile
# 15              Configurazione camera non disponibile
# 48  Intero appartamento • 2 camere da letto • 2 ba...
# 56  Intero appartamento • 1 camera da letto • 1 zo...
# 52              Configurazione camera non disponibile
# 46              Configurazione camera non disponibile
# 59  Intera casa vacanze • 2 camere da letto • 1 zo...
# 22  Intero appartamento • 1 camera da letto • 1 zo...
# 34  Intero appartamento • 1 camera da letto • 1 zo...
# 26  Intero appartamento • 1 camera da letto • 1 zo...
# 5               Configurazione camera non disponibile
# 9               Configurazione camera non disponibile
# 8               Configurazione camera non disponibile
# 6   Intero appartamento • 1 camera da letto • 1 zo...
# 28              Configurazione camera non disponibile
# 3               Configurazione camera non disponibile
# 7               Configurazione camera non disponibile
# 55              Configurazione camera non disponibile
# 58  Intero appartamento • 1 camera da letto • 1 zo...
# 57  Intero appartamento • 3 camere da letto • 1 zo...
# 64  Intero appartamento • 1 camera da letto • 1 zo...
# 60  Intera casa vacanze • 3 camere da letto • 1 ba...
# 53              Configurazione camera non disponibile
# 31  Intera casa vacanze • 1 camera da letto • 1 ba...
# 11              Configurazione camera non disponibile
# 45  Intero appartamento • 1 camera da letto • 1 zo...
# 44  Intero appartamento • 1 camera da letto • 1 zo...
# 12              Configurazione camera non disponibile
# 1               Configurazione camera non disponibile
# 65  Intero appartamento • 2 camere da letto • 1 ba...
# 67  Intero appartamento • 1 camera da letto • 1 zo...
# 66  Intero appartamento • 1 camera da letto • 1 zo...
# 29  Intero appartamento • 2 camere da letto • 1 zo...
# 0               Configurazione camera non disponibile
# 25              Configurazione camera non disponibile
# 17              Configurazione camera non disponibile
# 18                                      Suite privata
# 37  Intero appartamento • 1 camera da letto • 1 zo...
# 30              Configurazione camera non disponibile
# 42  Intero appartamento • 2 camere da letto • 1 zo...
# 40  Intero appartamento • 1 camera da letto • 1 zo...
# 32  Intero appartamento • 1 camera da letto • 2 zo...
# 43              Configurazione camera non disponibile
# 62              Configurazione camera non disponibile
# 54  Intero appartamento • 1 camera da letto • 1 zo...
# 68  Intero appartamento • 1 camera da letto • 1 zo...
# 21              Configurazione camera non disponibile
# 41  Intero appartamento • 1 camera da letto • 1 zo...
# 61  Intero appartamento • 1 camera da letto • 1 zo...
# 63  Intero appartamento • 1 camera da letto • 1 zo...
# 19              Configurazione camera non disponibile
# 33              Configurazione camera non disponibile
# 38  Intero appartamento • 1 camera da letto • 1 ba...
# 23              Configurazione camera non disponibile
# 47              Configurazione camera non disponibile
# 10  Intero appartamento • 1 camera da letto • 1 ba...
# 2               Configurazione camera non disponibile
# 35  Intero appartamento • 1 camera da letto • 1 zo...
# 4               Configurazione camera non disponibile
# 50      Intero monolocale • 1 bagno • 1 cucina • 70m²
# 51  Intero appartamento • 2 camere da letto • 1 zo...
# 49              Configurazione camera non disponibile
# 27  Intero appartamento • 1 camera da letto • 1 ba...
# 36  Intero appartamento • 1 camera da letto • 1 zo...
# 14              Configurazione camera non disponibile
# 39              Configurazione camera non disponibile
# 16  Intero appartamento • 2 camere da letto • 1 zo...
# 24              Configurazione camera non disponibile
# 13              Configurazione camera non disponibile
# 20  Intero appartamento • 1 camera da letto • 1 zo...
#
#                               descrizione_unprocessed
# 69  Appartamento con 2 Camere da Letto4 letti (2 s...
# 15  Camera Matrimoniale con Bagno Privato1 letto m...
# 48  Appartamento con 2 Camere da LettoIntero appar...
# 56  Appartamento - Piano TerraIntero appartamento ...
# 52  Ampia Camera Matrimoniale2 letti matrimonialiR...
# 46  Camera Matrimoniale con Bagno Privato1 letto m...
# 59  Casa con 2 Camere da LettoIntera casa vacanze ...
# 22  Appartamento con 1 Camera da LettoIntero appar...
# 34  Appartamento con Vista GiardinoIntero appartam...
# 26  Appartamento con 1 Camera da LettoIntero appar...
# 5   Camera Matrimoniale StandardLetti: 1 matrimoni...
# 9   Camera Matrimoniale/Doppia con Letti SingoliVa...
# 8   Camera King Superior 1 letto matrimoniale larg...
# 6   Appartamento MonolocaleIntero appartamento • 1...
# 28  Camera Matrimoniale Standard1 letto matrimonia...
# 3   Camera Matrimoniale1 letto matrimoniale alla f...
# 7   Camera King con Balcone 2 letti (1 singolo, 1 ...
# 55  Camera Matrimoniale1 letto matrimonialeColazio...
# 58  Appartamento AtticoIntero appartamento • 1 cam...
# 57  Appartamento con 3 Camere da LettoIntero appar...
# 64  Appartamento con 1 Camera da LettoIntero appar...
# 60  Casa Vacanze con 3 Camere da Letto Intera casa...
# 53  Appartamento con 1 Camera da Letto2 letti (1 d...
# 31  Casa con 1 Camera da LettoIntera casa vacanze ...
# 11  Camera Matrimoniale1 letto matrimonialeResta s...
# 45  Appartamento con 1 Camera da LettoIntero appar...
# 44  Appartamento con 1 Camera da LettoIntero appar...
# 12  Camera Matrimoniale Standard1 letto matrimonia...
# 1   Camera Doppia con Letti Singoli2 letti singoli...
# 65  Appartamento con 2 Camere da LettoIntero appar...
# 67  Appartamento con 1 Camera da LettoIntero appar...
# 66  Appartamento con 1 Camera da LettoIntero appar...
# 29  Appartamento con 2 Camere da LettoIntero appar...
# 0   Camera Doppia con Letti Singoli2 letti singoli...
# 25  Camera Classic Matrimoniale/Doppia con Letti S...
# 17  Camera Matrimoniale Deluxe1 letto matrimoniale...
# 18  Suite con Balcone Suite privata1 letto matrimo...
# 37  Appartamento - Piano TerraIntero appartamento ...
# 30  Camera Tripla Standard3 letti (2 singoli, 1 ma...
# 42  Appartamento con 3 Camere da LettoIntero appar...
# 40  Appartamento con 1 Camera da LettoIntero appar...
# 32  Appartamento con 1 Camera da LettoIntero appar...
# 43  Camera Matrimoniale con Vista Piscina1 letto m...
# 62  Camera Matrimoniale1 letto matrimonialeResta s...
# 54  Appartamento con 1 Camera da LettoIntero appar...
# 68  Appartamento con 1 Camera da LettoIntero appar...
# 21  Camera Matrimoniale1 letto matrimonialeResta s...
# 41  Appartamento con 1 Camera da LettoIntero appar...
# 61  Appartamento con 1 Camera da LettoIntero appar...
# 63  Appartamento con 1 Camera da LettoIntero appar...
# 19  Camera Matrimoniale con Bagno Privato1 letto m...
# 33  Camera Matrimoniale1 letto matrimonialeColazio...
# 38  Appartamento con 1 Camera da LettoIntero appar...
# 23  Appartamento con 2 Camere da Letto2 letti (1 m...
# 47  Camera Matrimoniale1 letto singoloResta solo 1...
# 10  Appartamento StandardIntero appartamento • 1 c...
# 2   Camera Matrimoniale con Bagno Privato Esterno ...
# 35  Appartamento con 1 Camera da LettoIntero appar...
# 4   Camera Tripla2 letti (1 singolo, 1 matrimonial...
# 50  MonolocaleIntero monolocale • 1 bagno • 1 cuci...
# 51  Appartamento Intero appartamento • 2 camere da...
# 49  Camera Standard Matrimoniale/Doppia con Letti ...
# 27  Appartamento con 1 Camera da LettoIntero appar...
# 36  Appartamento con Vista e BalconeIntero apparta...
# 14  Camera King con Balcone 2 letti (1 divano lett...
# 39  Appartamento con 1 Camera da Letto2 letti (1 m...
# 16  Appartamento con 2 Camere da LettoIntero appar...
# 24  Camera Matrimoniale1 letto matrimonialeRestano...
# 13  Camera Matrimoniale1 letto matrimoniale alla f...
# 20  Appartamento con 1 Camera da LettoIntero appar...
