# %% [markdown]
# # Introduzione

# %% [markdown]
# L'environment **anaconda** da utilizzare è **webscraping**.

# %% [markdown]
# # Importazione pacchetti

# %% [markdown]
# Importare i vari pacchetti necessari  per eseguire le azioni elencate nell'introduzione:
#    - selenium (per navigare sulle pagine web)
#    - request (scaricare dati da internet)
#    - bs4 (beautiful soup, manipolare gli html)
#    - os (navigare nei file del computer)
#    - pandas (manipolazione/esportazione dataframes)
#    - time (per i time sleep)
#    - datetime (gestire i timestamp, ovvero le stringhe contenti date e orari)
#    - tqdm (per le barre di progresso)
#    - re (lavorare con regex e le regular expressions)

# %%
#%% Pacchetti
## Importazione pacchetti per selenium
# Altre funzionalità di selenium
#from selenium.webdriver.support.ui import WebDriverWait
#from selenium.webdriver.common.by import By
#from selenium.webdriver.support import expected_conditions as EC
#from selenium.webdriver.common.action_chains import ActionChains
#from selenium.webdriver.chrome.options import Options
#from selenium.webdriver.common.keys import Keys
#from selenium.webdriver.common.actions.wheel_input import ScrollOrigin
#from selenium.common.exceptions import TimeoutException
#from webdriver_manager.chrome import ChromeDriverManager
#-------##-------##-------##-------##-------##-------##-------##-------##-------##-------#
import requests # Importazione pacchetti per scaricare dati da internet
from bs4 import BeautifulSoup # Importazione pacchetti per gestire HTML
import os # Interagire con i file del pc 
from tqdm import tqdm as tqdm # Importazione pacchetti per barra di progresso
import re # Importazione pacchetti per utilizzare regex e le regular expression
import pandas as pd  # Importazione pacchetti per lavorare con i dataframe
import warnings # Importazione pacchetti per gestire i warnings, ad esempio quelli di pandas
from datetime import datetime# Importazione pacchetti per lavorare con timestamps, orari e date
import numpy as np 

#pd.set_option('display.max_rows', None)

# %%
# Directory principale dello scraper, ove vi sono gli script e gli html devono essere posizionati
path_main_directory = '/Users/mattia/Desktop/Università/Data Science in Python/14) Web Scraping/Scraping-from-booking'

# %%
# Importare l'html del file in questione
with open(f"{path_main_directory}/html/html_final.txt","r") as f:
   html = f.read()

html_bs4 = BeautifulSoup(html,'html.parser')
proprietà = html_bs4.find_all("div",{"data-testid":"property-card"})

booking_dataframe = pd.DataFrame(columns=[
    "titolo",
    "recensione_voto_numerico",
    "recensione_voto_parola",
    "numero_recensioni",
    "date",
    "permanenza",
    "prezzo",
    "distanza_centro",
    "indirizzo",
    "stelle",
    "valutazione_booking",
    "descrizione_camera",
    "configurazione_camera",
    "descrizione_unprocessed"
])


for post in tqdm(proprietà):
   # Prendere il titolo della proprietà
   titolo = post.find("div",{"data-testid":"title"}).text
   
   # Selezionare la tag delle recensioni
   review = post.find("div",{"data-testid":"review-score"})#.text
   
   ## In caso di nuovi insererimenti  (novità su booking) non ci sono votazioni.
   if review != None:
      ## Estrarre voto numerico dalla tag delle recensioni
      recensione_voto_numerico = review.find("div",{"aria-hidden":"true"}).text

      ## Estrarre il voto in parole ed il numero di recensioni dalla tag delle recensioni
      info_recensioni = review.find("div",{"aria-hidden":"false"})
      for div in info_recensioni:
         if ("recensioni" in div.text.lower()) or ("recensione" in div.text.lower()):
            numero_recensioni = div.text

         else:
            recensione_voto_parola = div.text
   else:
      recensione_voto_numerico = "Novità su booking"
      numero_recensioni = "Novità su booking"
      recensione_voto_parola = "Novità su booking"
         

   # Selezionare la tag dei prezzi e per il numero di persone e notti
   info_costi = post.find("div",{"data-testid":"availability-rate-wrapper"})#.text

   ## Prezzo per notti e numero di persone
   permanenza =  info_costi.find("div",{"data-testid":"price-for-x-nights"}).text
   
   ## Prezzo
   prezzo =  info_costi.find("span",{"data-testid":"price-and-discounted-price"}).text


   # Selezionare la località
   ## Distanza dal centro
   distanza_centro = post.find("span",{"data-testid":"distance"}).text


   indirizzo = post.find("span",{"data-testid":"address"}).text


   # Valutazioni

   ## Rating stars
   rating_stars = post.find("div",{"data-testid":"rating-stars"})
   
   ### La proprietà potrebbe non essere un albergo e quindi non avere stelle
   if rating_stars != None:
      stelle = len(rating_stars.find_all("div"))
   else:
      stelle = np.nan
         
   ## Rating booking
   rating_booking = post.find("div",{"data-testid":"rating-squares"})
   
   ### La proprietà potrebbe  essere un albergo e quindi non avere valutazione booking
   if rating_booking != None:
      valutazione_booking = len(rating_booking.find_all("div"))
   else:
      valutazione_booking = np.nan


   # Descrizione della camera offerta
   
   ## Tutta la descrizione
   descrizione_unprocessed = post.find("div",{"data-testid":"recommended-units"}).text
   
   ## tag descrizione per estrarre cose estraibili
   descrizione = post.find("div",{"data-testid":"recommended-units"})

   ### Descrizione camera
   descrizione_camera = descrizione.find("h4").text
   
   ### Configurazione camera, che potrebbe non esistere 
   configurazione_camera = descrizione.find("div",{"data-testid":"property-card-unit-configuration"})

   if  configurazione_camera != None:
      configurazione_camera = configurazione_camera.text

   else:
      configurazione_camera = "Configurazione camera non disponibile"



   # Crea il dizionario con i dati della singola proprietà
   informazioni_singola_proprietà = {  "titolo": titolo,
                                       "recensione_voto_numerico": recensione_voto_numerico,
                                       "recensione_voto_parola": recensione_voto_parola,
                                       "numero_recensioni": numero_recensioni,
                                       "date": "1 agosto - 2 agosto",
                                       "permanenza": permanenza,
                                       "prezzo": prezzo,
                                       "distanza_centro": distanza_centro,
                                       "indirizzo": indirizzo,
                                       "stelle": stelle,
                                       "valutazione_booking": valutazione_booking,
                                       "descrizione_camera": descrizione_camera,
                                       "configurazione_camera": configurazione_camera,
                                       "descrizione_unprocessed": descrizione_unprocessed

                                    }
   
   # Aggiunge direttamente come nuova riga
   booking_dataframe.loc[len(booking_dataframe)] = informazioni_singola_proprietà
# Out:
# 100%|██████████| 43/43 [00:00<00:00, 444.51it/s]

# %%
booking_dataframe.to_csv(f"{path_main_directory}/bookingTerni.csv")

# %%
pd.set_option('display.max_rows', None)
booking_dataframe.sort_values(by="titolo")
# Out:
#                                         titolo recensione_voto_numerico  \
# 14                              A casa di Alma                      9,2
# 24                  Appartamenti Il Cerqueto 2                      8,2
# 35         Appartamenti Natura e Terra Marmore                      8,9
# 25                                    Aryhouse                      9,8
# 6                               Asso Residence                      8,2
# 10                       Asso Residence Centro                      7,9
# 7                          Asso Residence GOLD                      8,4
# 5                      Asso Residence Ospedale                      8,8
# 27                     Asso Residence Stazione                      7,9
# 21        Authentic Villa Surrounded by Nature                      9,6
# 8                             B&B Angolo Verde                      8,6
# 17                             B&B Villa Maria                      9,3
# 31                              Casa nel Verde                      7,8
# 20                                  Civico 100                      8,4
# 13                      Classic Hotel Tulipano                      7,5
# 0                                   Cospea B&B                      9,0
# 22                                 Domus Umbra                      8,3
# 28                                G&Gapartment                      7,8
# 2                               Hotel De Paris                      7,2
# 23                          Hotel Garden Terni                      7,8
# 15             Hotel Michelangelo Palace & SPA                      7,8
# 12                             Hotel Valentino                      8,5
# 38                           IL TEATRO ALLOGGI                      8,6
# 30                       Il Giardino di Venere                      8,1
# 42                        La Casa nella Contea                      9,9
# 32   La Casetta- Bilocale con giardino privato                      9,4
# 19                         Le Camere di Ettore                      8,9
# 34                                  M&M’s Home                      9,2
# 40  Palmira House - delizioso bilocale for two                      9,7
# 3                         Pied-à-terre ADELMA        Novità su booking
# 9                          Residence Viviverde                      8,8
# 1                           Rosy Bed&Breakfast                      9,0
# 36                          San Francesco Home                      8,8
# 11                  Santa Filomena Guest House                      9,7
# 18                         Tana per gli ospiti                      8,8
# 26                                 Tre Colonne                      9,1
# 37                 Tre Monumenti Luxury Suites                       10
# 16                                    Via Roma                      9,2
# 41                                     WHITE 2                      8,8
# 39                                Welcome home                      9,6
# 29                                       White                      8,6
# 4                                 angolo verde                      8,0
# 33                                   as maison                      9,5
#
#    recensione_voto_parola  numero_recensioni                 date  \
# 14            Eccellente      101 recensioni  1 agosto - 2 agosto
# 24                Ottimo      153 recensioni  1 agosto - 2 agosto
# 35              Favoloso      134 recensioni  1 agosto - 2 agosto
# 25           Eccezionale       27 recensioni  1 agosto - 2 agosto
# 6                 Ottimo    1.341 recensioni  1 agosto - 2 agosto
# 10                 Buono      980 recensioni  1 agosto - 2 agosto
# 7                 Ottimo       17 recensioni  1 agosto - 2 agosto
# 5               Favoloso    1.297 recensioni  1 agosto - 2 agosto
# 27                 Buono       61 recensioni  1 agosto - 2 agosto
# 21           Eccezionale       90 recensioni  1 agosto - 2 agosto
# 8               Favoloso      219 recensioni  1 agosto - 2 agosto
# 17            Eccellente      253 recensioni  1 agosto - 2 agosto
# 31                 Buono      141 recensioni  1 agosto - 2 agosto
# 20                Ottimo       49 recensioni  1 agosto - 2 agosto
# 13                 Buono      406 recensioni  1 agosto - 2 agosto
# 0             Eccellente      674 recensioni  1 agosto - 2 agosto
# 22                Ottimo      114 recensioni  1 agosto - 2 agosto
# 28                 Buono       89 recensioni  1 agosto - 2 agosto
# 2                  Buono      869 recensioni  1 agosto - 2 agosto
# 23                 Buono      477 recensioni  1 agosto - 2 agosto
# 15                 Buono      669 recensioni  1 agosto - 2 agosto
# 12                Ottimo      754 recensioni  1 agosto - 2 agosto
# 38              Favoloso      112 recensioni  1 agosto - 2 agosto
# 30                Ottimo       86 recensioni  1 agosto - 2 agosto
# 42           Eccezionale       21 recensioni  1 agosto - 2 agosto
# 32            Eccellente       56 recensioni  1 agosto - 2 agosto
# 19              Favoloso      103 recensioni  1 agosto - 2 agosto
# 34            Eccellente      168 recensioni  1 agosto - 2 agosto
# 40           Eccezionale      113 recensioni  1 agosto - 2 agosto
# 3       Novità su booking  Novità su booking  1 agosto - 2 agosto
# 9               Favoloso      620 recensioni  1 agosto - 2 agosto
# 1             Eccellente      330 recensioni  1 agosto - 2 agosto
# 36              Favoloso       17 recensioni  1 agosto - 2 agosto
# 11           Eccezionale       11 recensioni  1 agosto - 2 agosto
# 18              Favoloso       66 recensioni  1 agosto - 2 agosto
# 26            Eccellente       21 recensioni  1 agosto - 2 agosto
# 37           Eccezionale        3 recensioni  1 agosto - 2 agosto
# 16            Eccellente       76 recensioni  1 agosto - 2 agosto
# 41              Favoloso       19 recensioni  1 agosto - 2 agosto
# 39           Eccezionale       56 recensioni  1 agosto - 2 agosto
# 29              Favoloso      218 recensioni  1 agosto - 2 agosto
# 4                 Ottimo        7 recensioni  1 agosto - 2 agosto
# 33           Eccezionale      109 recensioni  1 agosto - 2 agosto
#
#            permanenza prezzo    distanza_centro indirizzo  stelle  \
# 14  1 notte, 2 adulti   € 81  1,2 km dal centro     Terni     NaN
# 24  1 notte, 2 adulti   € 74  1,7 km dal centro     Terni     NaN
# 35  1 notte, 2 adulti  € 113  5,5 km dal centro     Terni     NaN
# 25  1 notte, 2 adulti   € 85  1,1 km dal centro     Terni     NaN
# 6   1 notte, 2 adulti   € 79  2,1 km dal centro     Terni     NaN
# 10  1 notte, 2 adulti   € 81    40 m dal centro     Terni     NaN
# 7   1 notte, 2 adulti   € 94  1,9 km dal centro     Terni     NaN
# 5   1 notte, 2 adulti   € 89  1,9 km dal centro     Terni     NaN
# 27  1 notte, 2 adulti   € 94  1,1 km dal centro     Terni     NaN
# 21  1 notte, 2 adulti  € 110  7,8 km dal centro     Terni     NaN
# 8   1 notte, 2 adulti   € 69  2,6 km dal centro     Terni     NaN
# 17  1 notte, 2 adulti   € 74  2,7 km dal centro     Terni     NaN
# 31  1 notte, 2 adulti   € 59  2,8 km dal centro     Terni     NaN
# 20  1 notte, 2 adulti   € 72  0,8 km dal centro     Terni     NaN
# 13  1 notte, 2 adulti  € 128  1,7 km dal centro     Terni     3.0
# 0   1 notte, 2 adulti   € 55  1,7 km dal centro     Terni     NaN
# 22  1 notte, 2 adulti  € 183  4,7 km dal centro     Terni     NaN
# 28  1 notte, 2 adulti  € 129  1,5 km dal centro     Terni     NaN
# 2   1 notte, 2 adulti   € 69  0,9 km dal centro     Terni     3.0
# 23  1 notte, 2 adulti  € 138  1,2 km dal centro     Terni     4.0
# 15  1 notte, 2 adulti  € 174    1 km dal centro     Terni     4.0
# 12  1 notte, 2 adulti  € 183  0,9 km dal centro     Terni     4.0
# 38  1 notte, 2 adulti   € 93  0,8 km dal centro     Terni     NaN
# 30  1 notte, 2 adulti   € 74  5,5 km dal centro     Terni     NaN
# 42  1 notte, 2 adulti   € 99  5,4 km dal centro     Terni     NaN
# 32  1 notte, 2 adulti  € 109  1,3 km dal centro     Terni     NaN
# 19  1 notte, 2 adulti   € 79  1,1 km dal centro     Terni     NaN
# 34  1 notte, 2 adulti   € 85    1 km dal centro     Terni     NaN
# 40  1 notte, 2 adulti   € 94   400 m dal centro     Terni     NaN
# 3   1 notte, 2 adulti   € 53  1,1 km dal centro     Terni     NaN
# 9   1 notte, 2 adulti   € 76  3,6 km dal centro     Terni     NaN
# 1   1 notte, 2 adulti   € 77    1 km dal centro     Terni     NaN
# 36  1 notte, 2 adulti   € 84   400 m dal centro     Terni     NaN
# 11  1 notte, 2 adulti   € 74    1 km dal centro     Terni     NaN
# 18  1 notte, 2 adulti   € 81  2,3 km dal centro     Terni     NaN
# 26  1 notte, 2 adulti   € 76  0,5 km dal centro     Terni     NaN
# 37  1 notte, 2 adulti  € 113    1 km dal centro     Terni     NaN
# 16  1 notte, 2 adulti   € 84  0,7 km dal centro     Terni     NaN
# 41  1 notte, 2 adulti   € 73  0,8 km dal centro     Terni     NaN
# 39  1 notte, 2 adulti   € 87  0,6 km dal centro     Terni     NaN
# 29  1 notte, 2 adulti   € 67  0,6 km dal centro     Terni     NaN
# 4   1 notte, 2 adulti   € 63  2,6 km dal centro     Terni     NaN
# 33  1 notte, 2 adulti   € 89  2,3 km dal centro     Terni     NaN
#
#     valutazione_booking                                 descrizione_camera  \
# 14                  3.0              Camera Matrimoniale con Bagno Privato
# 24                  3.0                 Appartamento con 1 Camera da Letto
# 35                  3.0                    Appartamento con Vista Giardino
# 25                  3.0                 Appartamento con 1 Camera da Letto
# 6                   3.0                       Camera Matrimoniale Standard
# 10                  3.0       Camera Matrimoniale/Doppia con Letti Singoli
# 7                   3.0                              Camera King Superior
# 5                   3.0                            Appartamento Monolocale
# 27                  3.0                       Camera Matrimoniale Standard
# 21                  4.0                         Casa con 1 Camera da Letto
# 8                   3.0                                Camera Matrimoniale
# 17                  4.0                           Camera King con Balcone
# 31                  3.0                         Casa con 1 Camera da Letto
# 20                  3.0                                Camera Matrimoniale
# 13                  NaN                       Camera Matrimoniale Standard
# 0                   3.0                    Camera Doppia con Letti Singoli
# 22                  4.0                       Monolocale con Vista Piscina
# 28                  3.0                 Appartamento con 2 Camere da Letto
# 2                   NaN                    Camera Doppia con Letti Singoli
# 23                  NaN  Camera Classic Matrimoniale/Doppia con Letti S...
# 15                  NaN                         Camera Matrimoniale Deluxe
# 12                  NaN             Camera Matrimoniale Deluxe con Balcone
# 38                  3.0                         Appartamento - Piano Terra
# 30                  3.0                             Camera Tripla Standard
# 42                  3.0                 Appartamento con 1 Camera da Letto
# 32                  4.0                 Appartamento con 1 Camera da Letto
# 19                  3.0              Camera Matrimoniale con Bagno Privato
# 34                  3.0                                Camera Matrimoniale
# 40                  4.0                 Appartamento con 1 Camera da Letto
# 3                   NaN                 Appartamento con 2 Camere da Letto
# 9                   4.0                              Appartamento Standard
# 1                   4.0     Camera Matrimoniale con Bagno Privato Esterno
# 36                  3.0                 Appartamento con 1 Camera da Letto
# 11                  3.0                                      Camera Tripla
# 18                  3.0                                         Monolocale
# 26                  3.0                 Appartamento con 1 Camera da Letto
# 37                  3.0                   Appartamento con Vista e Balcone
# 16                  3.0                           Camera King con Balcone
# 41                  3.0                 Appartamento con 1 Camera da Letto
# 39                  4.0                 Appartamento con 2 Camere da Letto
# 29                  3.0                                Camera Matrimoniale
# 4                   NaN                                Camera Matrimoniale
# 33                  3.0                 Appartamento con 1 Camera da Letto
#
#                                 configurazione_camera  \
# 14              Configurazione camera non disponibile
# 24  Intero appartamento • 1 camera da letto • 1 zo...
# 35  Intero appartamento • 1 camera da letto • 1 zo...
# 25  Intero appartamento • 1 camera da letto • 1 zo...
# 6               Configurazione camera non disponibile
# 10              Configurazione camera non disponibile
# 7               Configurazione camera non disponibile
# 5   Intero appartamento • 1 camera da letto • 1 zo...
# 27              Configurazione camera non disponibile
# 21  Intera casa vacanze • 1 camera da letto • 1 zo...
# 8               Configurazione camera non disponibile
# 17              Configurazione camera non disponibile
# 31  Intera casa vacanze • 1 camera da letto • 1 ba...
# 20              Configurazione camera non disponibile
# 13              Configurazione camera non disponibile
# 0               Configurazione camera non disponibile
# 22                 Intero monolocale • 1 bagno • 21m²
# 28  Intero appartamento • 2 camere da letto • 1 zo...
# 2               Configurazione camera non disponibile
# 23              Configurazione camera non disponibile
# 15              Configurazione camera non disponibile
# 12              Configurazione camera non disponibile
# 38  Intero appartamento • 1 camera da letto • 1 zo...
# 30              Configurazione camera non disponibile
# 42  Intero appartamento • 1 camera da letto • 1 zo...
# 32  Intero appartamento • 1 camera da letto • 2 zo...
# 19              Configurazione camera non disponibile
# 34              Configurazione camera non disponibile
# 40  Intero appartamento • 1 camera da letto • 1 ba...
# 3               Configurazione camera non disponibile
# 9   Intero appartamento • 1 camera da letto • 1 ba...
# 1               Configurazione camera non disponibile
# 36  Intero appartamento • 1 camera da letto • 1 zo...
# 11              Configurazione camera non disponibile
# 18      Intero monolocale • 1 bagno • 1 cucina • 70m²
# 26  Intero appartamento • 1 camera da letto • 1 ba...
# 37  Intero appartamento • 1 camera da letto • 1 zo...
# 16              Configurazione camera non disponibile
# 41              Configurazione camera non disponibile
# 39  Intero appartamento • 2 camere da letto • 1 zo...
# 29              Configurazione camera non disponibile
# 4               Configurazione camera non disponibile
# 33  Intero appartamento • 1 camera da letto • 1 zo...
#
#                               descrizione_unprocessed
# 14  Camera Matrimoniale con Bagno Privato1 letto m...
# 24  Appartamento con 1 Camera da LettoIntero appar...
# 35  Appartamento con Vista GiardinoIntero appartam...
# 25  Appartamento con 1 Camera da LettoIntero appar...
# 6   Camera Matrimoniale StandardLetti: 1 matrimoni...
# 10  Camera Matrimoniale/Doppia con Letti SingoliVa...
# 7   Camera King Superior 1 letto matrimoniale larg...
# 5   Appartamento MonolocaleIntero appartamento • 1...
# 27  Camera Matrimoniale Standard1 letto matrimonia...
# 21  Casa con 1 Camera da LettoIntera casa vacanze ...
# 8   Camera Matrimoniale1 letto matrimoniale alla f...
# 17  Camera King con Balcone 2 letti (1 singolo, 1 ...
# 31  Casa con 1 Camera da LettoIntera casa vacanze ...
# 20  Camera Matrimoniale1 letto matrimonialeResta s...
# 13  Camera Matrimoniale Standard1 letto matrimonia...
# 0   Camera Doppia con Letti Singoli2 letti singoli...
# 22  Monolocale con Vista PiscinaIntero monolocale ...
# 28  Appartamento con 2 Camere da LettoIntero appar...
# 2   Camera Doppia con Letti Singoli2 letti singoli...
# 23  Camera Classic Matrimoniale/Doppia con Letti S...
# 15  Camera Matrimoniale Deluxe1 letto matrimoniale...
# 12  Camera Matrimoniale Deluxe con Balcone1 letto ...
# 38  Appartamento - Piano TerraIntero appartamento ...
# 30  Camera Tripla Standard3 letti (2 singoli, 1 ma...
# 42  Appartamento con 1 Camera da LettoIntero appar...
# 32  Appartamento con 1 Camera da LettoIntero appar...
# 19  Camera Matrimoniale con Bagno Privato1 letto m...
# 34  Camera Matrimoniale1 letto matrimonialeColazio...
# 40  Appartamento con 1 Camera da LettoIntero appar...
# 3   Appartamento con 2 Camere da Letto2 letti (1 m...
# 9   Appartamento StandardIntero appartamento • 1 c...
# 1   Camera Matrimoniale con Bagno Privato Esterno ...
# 36  Appartamento con 1 Camera da LettoIntero appar...
# 11  Camera Tripla2 letti (1 singolo, 1 matrimonial...
# 18  MonolocaleIntero monolocale • 1 bagno • 1 cuci...
# 26  Appartamento con 1 Camera da LettoIntero appar...
# 37  Appartamento con Vista e BalconeIntero apparta...
# 16  Camera King con Balcone 2 letti (1 divano lett...
# 41  Appartamento con 1 Camera da Letto2 letti (1 m...
# 39  Appartamento con 2 Camere da LettoIntero appar...
# 29  Camera Matrimoniale1 letto matrimonialeRestano...
# 4   Camera Matrimoniale1 letto matrimoniale alla f...
# 33  Appartamento con 1 Camera da LettoIntero appar...
